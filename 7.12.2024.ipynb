# %%
surah_info = [
    {"number": 1, "name_english": "Al-Fatiha", "name_urdu": "الفاتحہ", "number_of_verses": 7},
    {"number": 2, "name_english": "Al-Baqara", "name_urdu": "البقرہ", "number_of_verses": 286},
    {"number": 3, "name_english": "Aal-E-Imran", "name_urdu": "آل عمران", "number_of_verses": 200},
    {"number": 4, "name_english": "An-Nisa", "name_urdu": "النساء", "number_of_verses": 176},
    {"number": 5, "name_english": "Al-Ma'idah", "name_urdu": "المائدہ", "number_of_verses": 120},
    {"number": 6, "name_english": "Al-An'am", "name_urdu": "الانعام", "number_of_verses": 165},
    {"number": 7, "name_english": "Al-A'raf", "name_urdu": "الاعراف", "number_of_verses": 206},
    {"number": 8, "name_english": "Al-Anfal", "name_urdu": "الانفال", "number_of_verses": 75},
    {"number": 9, "name_english": "At-Tawbah", "name_urdu": "التوبہ", "number_of_verses": 129},
    {"number": 10, "name_english": "Yunus", "name_urdu": "یونس", "number_of_verses": 109},
    {"number": 11, "name_english": "Hud", "name_urdu": "ہود", "number_of_verses": 123},
    {"number": 12, "name_english": "Yusuf", "name_urdu": "یوسف", "number_of_verses": 111},
    {"number": 13, "name_english": "Ar-Ra'd", "name_urdu": "الرعد", "number_of_verses": 43},
    {"number": 14, "name_english": "Ibrahim", "name_urdu": "ابراہیم", "number_of_verses": 52},
    {"number": 15, "name_english": "Al-Hijr", "name_urdu": "الحجر", "number_of_verses": 99},
    {"number": 16, "name_english": "An-Nahl", "name_urdu": "النحل", "number_of_verses": 128},
    {"number": 17, "name_english": "Al-Isra", "name_urdu": "بنی اسرائیل", "number_of_verses": 111},
    {"number": 18, "name_english": "Al-Kahf", "name_urdu": "الکہف", "number_of_verses": 110},
    {"number": 19, "name_english": "Maryam", "name_urdu": "مریم", "number_of_verses": 98},
    {"number": 20, "name_english": "Ta-Ha", "name_urdu": "طٰہٰ", "number_of_verses": 135},
    {"number": 21, "name_english": "Al-Anbiya", "name_urdu": "الانبیا", "number_of_verses": 112},
    {"number": 22, "name_english": "Al-Hajj", "name_urdu": "الحج", "number_of_verses": 78},
    {"number": 23, "name_english": "Al-Mu'minun", "name_urdu": "المؤمنون", "number_of_verses": 118},
    {"number": 24, "name_english": "An-Nur", "name_urdu": "النور", "number_of_verses": 64},
    {"number": 25, "name_english": "Al-Furqan", "name_urdu": "الفرقان", "number_of_verses": 77},
    {"number": 26, "name_english": "Ash-Shu'ara", "name_urdu": "الشعراء", "number_of_verses": 227},
    {"number": 27, "name_english": "An-Naml", "name_urdu": "النمل", "number_of_verses": 93},
    {"number": 28, "name_english": "Al-Qasas", "name_urdu": "القصص", "number_of_verses": 88},
    {"number": 29, "name_english": "Al-Ankabut", "name_urdu": "العنکبوت", "number_of_verses": 69},
    {"number": 30, "name_english": "Ar-Rum", "name_urdu": "الروم", "number_of_verses": 60},
    {"number": 31, "name_english": "Luqman", "name_urdu": "لقمان", "number_of_verses": 34},
    {"number": 32, "name_english": "As-Sajda", "name_urdu": "السجدہ", "number_of_verses": 30},
    {"number": 33, "name_english": "Al-Ahzab", "name_urdu": "الاحزاب", "number_of_verses": 73},
    {"number": 34, "name_english": "Saba", "name_urdu": "سبا", "number_of_verses": 54},
    {"number": 35, "name_english": "Fatir", "name_urdu": "فاطر", "number_of_verses": 45},
    {"number": 36, "name_english": "Ya-Sin", "name_urdu": "یٰس", "number_of_verses": 83},
    {"number": 37, "name_english": "As-Saffat", "name_urdu": "الصافات", "number_of_verses": 182},
    {"number": 38, "name_english": "Sad", "name_urdu": "ص", "number_of_verses": 88},
    {"number": 39, "name_english": "Az-Zumar", "name_urdu": "الزمر", "number_of_verses": 75},
    {"number": 40, "name_english": "Ghafir", "name_urdu": "غافر", "number_of_verses": 85},
    {"number": 41, "name_english": "Fussilat", "name_urdu": "حم السجدہ", "number_of_verses": 54},
    {"number": 42, "name_english": "Ash-Shura", "name_urdu": "الشورٰی", "number_of_verses": 53},
    {"number": 43, "name_english": "Az-Zukhruf", "name_urdu": "الزخرف", "number_of_verses": 89},
    {"number": 44, "name_english": "Ad-Dukhan", "name_urdu": "الدخان", "number_of_verses": 59},
    {"number": 45, "name_english": "Al-Jathiya", "name_urdu": "الجاثیہ", "number_of_verses": 37},
    {"number": 46, "name_english": "Al-Ahqaf", "name_urdu": "الاحقاف", "number_of_verses": 35},
    {"number": 47, "name_english": "Muhammad", "name_urdu": "محمد", "number_of_verses": 38},
    {"number": 48, "name_english": "Al-Fath", "name_urdu": "الفتح", "number_of_verses": 29},
    {"number": 49, "name_english": "Al-Hujurat", "name_urdu": "الحجرات", "number_of_verses": 18},
    {"number": 50, "name_english": "Qaf", "name_urdu": "ق", "number_of_verses": 45},
    {"number": 51, "name_english": "Adh-Dhariyat", "name_urdu": "الذاریات", "number_of_verses": 60},
    {"number": 52, "name_english": "At-Tur", "name_urdu": "الطور", "number_of_verses": 49},
    {"number": 53, "name_english": "An-Najm", "name_urdu": "النجم", "number_of_verses": 62},
    {"number": 54, "name_english": "Al-Qamar", "name_urdu": "القمر", "number_of_verses": 55},
    {"number": 55, "name_english": "Ar-Rahman", "name_urdu": "الرحمن", "number_of_verses": 78},
    {"number": 56, "name_english": "Al-Waqi'a", "name_urdu": "الواقعہ", "number_of_verses": 96},
    {"number": 57, "name_english": "Al-Hadid", "name_urdu": "الحدید", "number_of_verses": 29},
    {"number": 58, "name_english": "Al-Mujadila", "name_urdu": "المجادلہ", "number_of_verses": 22},
    {"number": 59, "name_english": "Al-Hashr", "name_urdu": "الحشر", "number_of_verses": 24},
    {"number": 60, "name_english": "Al-Mumtahina", "name_urdu": "الممتحنہ", "number_of_verses": 13},
    {"number": 61, "name_english": "As-Saff", "name_urdu": "الصف", "number_of_verses": 14},
    {"number": 62, "name_english": "Al-Jumu'a", "name_urdu": "الجمعہ", "number_of_verses": 11},
    {"number": 63, "name_english": "Al-Munafiqun", "name_urdu": "المنافقون", "number_of_verses": 11},
    {"number": 64, "name_english": "At-Taghabun", "name_urdu": "التغابن", "number_of_verses": 18},
    {"number": 65, "name_english": "At-Talaq", "name_urdu": "الطلاق", "number_of_verses": 12},
    {"number": 66, "name_english": "At-Tahrim", "name_urdu": "التحریم", "number_of_verses": 12},
    {"number": 67, "name_english": "Al-Mulk", "name_urdu": "الملک", "number_of_verses": 30},
    {"number": 68, "name_english": "Al-Qalam", "name_urdu": "القلم", "number_of_verses": 52},
    {"number": 69, "name_english": "Al-Haaqqa", "name_urdu": "الحاقہ", "number_of_verses": 52},
    {"number": 70, "name_english": "Al-Ma'arij", "name_urdu": "المعارج", "number_of_verses": 44},
    {"number": 71, "name_english": "Nuh", "name_urdu": "نوح", "number_of_verses": 28},
    {"number": 72, "name_english": "Al-Jinn", "name_urdu": "الجن", "number_of_verses": 28},
    {"number": 73, "name_english": "Al-Muzzammil", "name_urdu": "المزمل", "number_of_verses": 20},
    {"number": 74, "name_english": "Al-Muddaththir", "name_urdu": "المدثر", "number_of_verses": 56},
    {"number": 75, "name_english": "Al-Qiyama", "name_urdu": "القیامہ", "number_of_verses": 40},
    {"number": 76, "name_english": "Al-Insan", "name_urdu": "الانسان", "number_of_verses": 31},]
for surah in surah_info:
    # print(f"\n {surah["number_of_verses"]}")
    # for surah in surah_info:
    # print(f" {surah['name_urdo']}")
    print(f" \n the number of surah is {surah['number']}.")
    print(f" surah name_english is {surah['name_english']}.")
    print(f" surah name_urdu {surah['name_urdu']}.") 
    print(f" surah num_of_verses {surah['number_of_verses']}.")
# Out:
#
#  the number of surah is 1.
#  surah name_english is Al-Fatiha.
#  surah name_urdu الفاتحہ.
#  surah num_of_verses 7.
#
#  the number of surah is 2.
#  surah name_english is Al-Baqara.
#  surah name_urdu البقرہ.
#  surah num_of_verses 286.
#
#  the number of surah is 3.
#  surah name_english is Aal-E-Imran.
#  surah name_urdu آل عمران.
#  surah num_of_verses 200.
#
#  the number of surah is 4.
#  surah name_english is An-Nisa.
#  surah name_urdu النساء.
#  surah num_of_verses 176.
#
#  the number of surah is 5.
#  surah name_english is Al-Ma'idah.
#  surah name_urdu المائدہ.
#  surah num_of_verses 120.
#
#  the number of surah is 6.
#  surah name_english is Al-An'am.
#  surah name_urdu الانعام.
#  surah num_of_verses 165.
#
#  the number of surah is 7.
#  surah name_english is Al-A'raf.
#  surah name_urdu الاعراف.
#  surah num_of_verses 206.
#
#  the number of surah is 8.
#  surah name_english is Al-Anfal.
#  surah name_urdu الانفال.
#  surah num_of_verses 75.
#
#  the number of surah is 9.
#  surah name_english is At-Tawbah.
#  surah name_urdu التوبہ.
#  surah num_of_verses 129.
#
#  the number of surah is 10.
#  surah name_english is Yunus.
#  surah name_urdu یونس.
#  surah num_of_verses 109.
#
#  the number of surah is 11.
#  surah name_english is Hud.
#  surah name_urdu ہود.
#  surah num_of_verses 123.
#
#  the number of surah is 12.
#  surah name_english is Yusuf.
#  surah name_urdu یوسف.
#  surah num_of_verses 111.
#
#  the number of surah is 13.
#  surah name_english is Ar-Ra'd.
#  surah name_urdu الرعد.
#  surah num_of_verses 43.
#
#  the number of surah is 14.
#  surah name_english is Ibrahim.
#  surah name_urdu ابراہیم.
#  surah num_of_verses 52.
#
#  the number of surah is 15.
#  surah name_english is Al-Hijr.
#  surah name_urdu الحجر.
#  surah num_of_verses 99.
#
#  the number of surah is 16.
#  surah name_english is An-Nahl.
#  surah name_urdu النحل.
#  surah num_of_verses 128.
#
#  the number of surah is 17.
#  surah name_english is Al-Isra.
#  surah name_urdu بنی اسرائیل.
#  surah num_of_verses 111.
#
#  the number of surah is 18.
#  surah name_english is Al-Kahf.
#  surah name_urdu الکہف.
#  surah num_of_verses 110.
#
#  the number of surah is 19.
#  surah name_english is Maryam.
#  surah name_urdu مریم.
#  surah num_of_verses 98.
#
#  the number of surah is 20.
#  surah name_english is Ta-Ha.
#  surah name_urdu طٰہٰ.
#  surah num_of_verses 135.
#
#  the number of surah is 21.
#  surah name_english is Al-Anbiya.
#  surah name_urdu الانبیا.
#  surah num_of_verses 112.
#
#  the number of surah is 22.
#  surah name_english is Al-Hajj.
#  surah name_urdu الحج.
#  surah num_of_verses 78.
#
#  the number of surah is 23.
#  surah name_english is Al-Mu'minun.
#  surah name_urdu المؤمنون.
#  surah num_of_verses 118.
#
#  the number of surah is 24.
#  surah name_english is An-Nur.
#  surah name_urdu النور.
#  surah num_of_verses 64.
#
#  the number of surah is 25.
#  surah name_english is Al-Furqan.
#  surah name_urdu الفرقان.
#  surah num_of_verses 77.
#
#  the number of surah is 26.
#  surah name_english is Ash-Shu'ara.
#  surah name_urdu الشعراء.
#  surah num_of_verses 227.
#
#  the number of surah is 27.
#  surah name_english is An-Naml.
#  surah name_urdu النمل.
#  surah num_of_verses 93.
#
#  the number of surah is 28.
#  surah name_english is Al-Qasas.
#  surah name_urdu القصص.
#  surah num_of_verses 88.
#
#  the number of surah is 29.
#  surah name_english is Al-Ankabut.
#  surah name_urdu العنکبوت.
#  surah num_of_verses 69.
#
#  the number of surah is 30.
#  surah name_english is Ar-Rum.
#  surah name_urdu الروم.
#  surah num_of_verses 60.
#
#  the number of surah is 31.
#  surah name_english is Luqman.
#  surah name_urdu لقمان.
#  surah num_of_verses 34.
#
#  the number of surah is 32.
#  surah name_english is As-Sajda.
#  surah name_urdu السجدہ.
#  surah num_of_verses 30.
#
#  the number of surah is 33.
#  surah name_english is Al-Ahzab.
#  surah name_urdu الاحزاب.
#  surah num_of_verses 73.
#
#  the number of surah is 34.
#  surah name_english is Saba.
#  surah name_urdu سبا.
#  surah num_of_verses 54.
#
#  the number of surah is 35.
#  surah name_english is Fatir.
#  surah name_urdu فاطر.
#  surah num_of_verses 45.
#
#  the number of surah is 36.
#  surah name_english is Ya-Sin.
#  surah name_urdu یٰس.
#  surah num_of_verses 83.
#
#  the number of surah is 37.
#  surah name_english is As-Saffat.
#  surah name_urdu الصافات.
#  surah num_of_verses 182.
#
#  the number of surah is 38.
#  surah name_english is Sad.
#  surah name_urdu ص.
#  surah num_of_verses 88.
#
#  the number of surah is 39.
#  surah name_english is Az-Zumar.
#  surah name_urdu الزمر.
#  surah num_of_verses 75.
#
#  the number of surah is 40.
#  surah name_english is Ghafir.
#  surah name_urdu غافر.
#  surah num_of_verses 85.
#
#  the number of surah is 41.
#  surah name_english is Fussilat.
#  surah name_urdu حم السجدہ.
#  surah num_of_verses 54.
#
#  the number of surah is 42.
#  surah name_english is Ash-Shura.
#  surah name_urdu الشورٰی.
#  surah num_of_verses 53.
#
#  the number of surah is 43.
#  surah name_english is Az-Zukhruf.
#  surah name_urdu الزخرف.
#  surah num_of_verses 89.
#
#  the number of surah is 44.
#  surah name_english is Ad-Dukhan.
#  surah name_urdu الدخان.
#  surah num_of_verses 59.
#
#  the number of surah is 45.
#  surah name_english is Al-Jathiya.
#  surah name_urdu الجاثیہ.
#  surah num_of_verses 37.
#
#  the number of surah is 46.
#  surah name_english is Al-Ahqaf.
#  surah name_urdu الاحقاف.
#  surah num_of_verses 35.
#
#  the number of surah is 47.
#  surah name_english is Muhammad.
#  surah name_urdu محمد.
#  surah num_of_verses 38.
#
#  the number of surah is 48.
#  surah name_english is Al-Fath.
#  surah name_urdu الفتح.
#  surah num_of_verses 29.
#
#  the number of surah is 49.
#  surah name_english is Al-Hujurat.
#  surah name_urdu الحجرات.
#  surah num_of_verses 18.
#
#  the number of surah is 50.
#  surah name_english is Qaf.
#  surah name_urdu ق.
#  surah num_of_verses 45.
#
#  the number of surah is 51.
#  surah name_english is Adh-Dhariyat.
#  surah name_urdu الذاریات.
#  surah num_of_verses 60.
#
#  the number of surah is 52.
#  surah name_english is At-Tur.
#  surah name_urdu الطور.
#  surah num_of_verses 49.
#
#  the number of surah is 53.
#  surah name_english is An-Najm.
#  surah name_urdu النجم.
#  surah num_of_verses 62.
#
#  the number of surah is 54.
#  surah name_english is Al-Qamar.
#  surah name_urdu القمر.
#  surah num_of_verses 55.
#
#  the number of surah is 55.
#  surah name_english is Ar-Rahman.
#  surah name_urdu الرحمن.
#  surah num_of_verses 78.
#
#  the number of surah is 56.
#  surah name_english is Al-Waqi'a.
#  surah name_urdu الواقعہ.
#  surah num_of_verses 96.
#
#  the number of surah is 57.
#  surah name_english is Al-Hadid.
#  surah name_urdu الحدید.
#  surah num_of_verses 29.
#
#  the number of surah is 58.
#  surah name_english is Al-Mujadila.
#  surah name_urdu المجادلہ.
#  surah num_of_verses 22.
#
#  the number of surah is 59.
#  surah name_english is Al-Hashr.
#  surah name_urdu الحشر.
#  surah num_of_verses 24.
#
#  the number of surah is 60.
#  surah name_english is Al-Mumtahina.
#  surah name_urdu الممتحنہ.
#  surah num_of_verses 13.
#
#  the number of surah is 61.
#  surah name_english is As-Saff.
#  surah name_urdu الصف.
#  surah num_of_verses 14.
#
#  the number of surah is 62.
#  surah name_english is Al-Jumu'a.
#  surah name_urdu الجمعہ.
#  surah num_of_verses 11.
#
#  the number of surah is 63.
#  surah name_english is Al-Munafiqun.
#  surah name_urdu المنافقون.
#  surah num_of_verses 11.
#
#  the number of surah is 64.
#  surah name_english is At-Taghabun.
#  surah name_urdu التغابن.
#  surah num_of_verses 18.
#
#  the number of surah is 65.
#  surah name_english is At-Talaq.
#  surah name_urdu الطلاق.
#  surah num_of_verses 12.
#
#  the number of surah is 66.
#  surah name_english is At-Tahrim.
#  surah name_urdu التحریم.
#  surah num_of_verses 12.
#
#  the number of surah is 67.
#  surah name_english is Al-Mulk.
#  surah name_urdu الملک.
#  surah num_of_verses 30.
#
#  the number of surah is 68.
#  surah name_english is Al-Qalam.
#  surah name_urdu القلم.
#  surah num_of_verses 52.
#
#  the number of surah is 69.
#  surah name_english is Al-Haaqqa.
#  surah name_urdu الحاقہ.
#  surah num_of_verses 52.
#
#  the number of surah is 70.
#  surah name_english is Al-Ma'arij.
#  surah name_urdu المعارج.
#  surah num_of_verses 44.
#
#  the number of surah is 71.
#  surah name_english is Nuh.
#  surah name_urdu نوح.
#  surah num_of_verses 28.
#
#  the number of surah is 72.
#  surah name_english is Al-Jinn.
#  surah name_urdu الجن.
#  surah num_of_verses 28.
#
#  the number of surah is 73.
#  surah name_english is Al-Muzzammil.
#  surah name_urdu المزمل.
#  surah num_of_verses 20.
#
#  the number of surah is 74.
#  surah name_english is Al-Muddaththir.
#  surah name_urdu المدثر.
#  surah num_of_verses 56.
#
#  the number of surah is 75.
#  surah name_english is Al-Qiyama.
#  surah name_urdu القیامہ.
#  surah num_of_verses 40.
#
#  the number of surah is 76.
#  surah name_english is Al-Insan.
#  surah name_urdu الانسان.
#  surah num_of_verses 31.

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x, y in thisdict .items():
  print(f"\n{x}:")
  print(f"{y}.")
# Out:
# brand:
# Ford.
#
# model:
# Mustang.
#
# year:
# 1964.

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x, y in thisdict. items():
    print(f"\n{x}:")
    print(f"{y}.")
# Out:
# brand:
# Ford.
#
# model:
# Mustang.
#
# year:
# 1964.

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict.keys():
    print(x)
# Out:
# brand
# model
# year

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x, y in thisdict.items():
    print(x, y)
# Out:
# brand Ford
# model Mustang
# year 1964
